# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Final_dataset4.csv")

# %%
df
# Out:
#          Source Port   Destination Port   Protocol   Flow Duration  \
# 0              60015                 80          6               1
# 1                 80              60015          6              47
# 2              60015                 80          6               1
# 3                443              60007          6         8001234
# 4              55310                443          6       112729696
# ...              ...                ...        ...             ...
# 121981         49497              64965          6               1
# 121982         64068              64068          6        14075036
# 121983         47148              47148          6              48
# 121984         49498              55027          6             116
# 121985         62459              62459          6               1
#
#          Total Fwd Packets   Total Backward Packets  \
# 0                        2                        0
# 1                        2                        0
# ...

# %%
df.shape
# Out:
# (121986, 80)

# %%
df = df.drop([' Bwd PSH Flags', ' Fwd URG Flags', ' Bwd URG Flags', 'FIN Flag Count', ' PSH Flag Count',
               ' ECE Flag Count', 'Fwd Avg Bytes/Bulk', ' Fwd Avg Packets/Bulk', ' Fwd Avg Bulk Rate', 
               ' Bwd Avg Bytes/Bulk', ' Bwd Avg Packets/Bulk', 'Bwd Avg Bulk Rate'], axis = 1)

# %%
df
# Out:
#          Source Port   Destination Port   Protocol   Flow Duration  \
# 0              60015                 80          6               1
# 1                 80              60015          6              47
# 2              60015                 80          6               1
# 3                443              60007          6         8001234
# 4              55310                443          6       112729696
# ...              ...                ...        ...             ...
# 121981         49497              64965          6               1
# 121982         64068              64068          6        14075036
# 121983         47148              47148          6              48
# 121984         49498              55027          6             116
# 121985         62459              62459          6               1
#
#          Total Fwd Packets   Total Backward Packets  \
# 0                        2                        0
# 1                        2                        0
# ...

# %%
df.shape
# Out:
# (121986, 68)

# %%
df[' Label'].unique()
# Out:
# array([ 0,  2,  4,  1,  3,  5,  6,  7,  8,  9, 10, 11, 12])

# %%
X = df[[' ACK Flag Count',
        ' Avg Fwd Segment Size', 
        ' Fwd Packet Length Mean', 
        ' Packet Length Mean',
         ' Min Packet Length', 
        ' Fwd Packet Length Min',
        ' Average Packet Size', 
        ' Protocol', 
         ' Fwd Packet Length Max', 
        ' Inbound', 
        ' Source Port', 
        ' Max Packet Length',
        ' URG Flag Count',
         'Fwd Packets/s',
        ' Down/Up Ratio', 
        'Init_Win_bytes_forward',
        ' act_data_pkt_fwd',
         ' Fwd IAT Mean',
        ' Flow IAT Std',
        ' Fwd IAT Std', 
        ' Flow Duration',
        'Fwd IAT Total', 
         ' Idle Max', 
        ' Flow IAT Max',
        ' Fwd IAT Max',
        'Fwd PSH Flags',
        ' Fwd Header Length.1',
        ' min_seg_size_forward',
        ' Subflow Fwd Bytes'
       # 'Total Length of Fwd Packets',
        #' Subflow Fwd Bytes',
         #       ' Destination Port',
         ]]

# %%
X.shape
# Out:
# (121986, 29)

# %%
import seaborn as sns
sns.countplot(df[' Label'], label = "Label")
# Out:
# <AxesSubplot:xlabel=' Label', ylabel='count'>

# %%
#X = df.drop([' Label'], axis = 1).values
y = df[' Label'].values

# %%
from sklearn.feature_selection import f_classif,SelectKBest, chi2

#features = SelectKBest(score_func = f_classif, k = 27)
#X_features = features.fit_transform(X, y)

# %%
#X_features.shape

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler, MaxAbsScaler
scaler = StandardScaler()
# from sklearn.decomposition import PCA
# pca = PCA(n_components = 15)
# X_features4 = pca.fit_transform(X_features)
X_features = scaler.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_features, y, random_state = 17, test_size = 0.2)
#X_train3, X_test3, y_train3, y_test3 = train_test_split(X_features3, y3, random_state = 0, test_size = 0.2)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
# from collections import Counter

# def euclidean(x1, x2):
#     return np.sqrt(np.sum(x1-x2)**2)

# class KNN:
#     def __init__(self, k=3):
#         self.k = k
        
#     def fit(self, X, y):
#         self.X_train = X
#         self.y_train = y
    
#     def predict(self, X):
#         predicted_labels = [self._predict(x) for x in X]
#         return np.array(predicted_labels)
    
#     def _predict(self, x):
#         distances = [euclidean(x, x_train) for x_train in self.X_train]
        
#         k_indices = np.argsort(distances)[:self.k]
#         k_nearest_labels = [self.y_train[i] for i in k_indices]
#         most_common = Counter(k_nearest_labels).most_common(1)
#         return most_common[0][0]

# %%
classifier_knn = KNeighborsClassifier(n_neighbors = 7)
classifier_knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=7, p=2,
#                      weights='uniform')

# %%
pred_knn = classifier_knn.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix
print(classification_report(y_test, pred_knn))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      1991
#            1       0.62      0.81      0.70      1903
#            2       0.96      0.96      0.96      2067
#            3       0.94      0.92      0.93      1916
#            4       0.98      0.99      0.98      2056
#            5       0.99      1.00      0.99      2015
#            6       0.96      0.98      0.97      2047
#            7       0.86      0.69      0.76       352
#            8       0.95      0.91      0.93      1993
#            9       0.94      0.96      0.95      1960
#           10       0.73      0.55      0.63      2052
#           11       0.96      0.95      0.95      1964
#           12       0.99      0.99      0.99      2082
#
#     accuracy                           0.91     24398
#    macro avg       0.91      0.90      0.90     24398
# weighted avg       0.92      0.91      0.91     24398

# %%
cm = confusion_matrix(y_test, pred_knn)

# %%
sns.heatmap(cm)
# Out:
# <AxesSubplot:>

# %%
# from sklearn.model_selection import GridSearchCV
# from sklearn.svm import SVC

# param_grid = {'C': [0.1, 1, 10, 100], 'gamma': [1, 0.1, 0.01, 0.001]} 
# grid4 = GridSearchCV(SVC(probability = True),param_grid,refit=True,verbose=4)
# grid3 = GridSearchCV(SVC(probability = True),param_grid,refit=True,verbose=4, )
# grid4.fit(X_train4, y_train4)
# grid3.fit(X_train3, y_train3)

# %%
# pred_svc4 = grid4.predict(X_test4)
# pred_svc3 = grid3.predict(X_test3)

# print(classification_report(y_test4, pred_svc4))

# print(classification_report(y_test4, pred_svc3))
